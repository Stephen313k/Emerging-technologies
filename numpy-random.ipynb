# %% [markdown]
# # The Numpy Random Package
#
# [Official documentation](https://numpy.org/doc/stable/reference/random/index.html)
#
# ***

# %%
# Efficient numerical arrays
import numpy as np
# Plotting
import matplotlib.pyplot as plt

# %%
# Change default style sheet
plt.style.use('fivethirtyeight')

# Change the default figure size
plt.rcParams['figure.figsize'] = [15, 10]

# %% [markdown]
# <br>
#
# ## numpy.random.normal
#
# https://numpy.org/doc/stable/reference/random/generated/numpy.random.normal.html
#
# ***

# %% [markdown]
# Seeding is important in random number generation [1]

# %%
mu, sigma = 0, 0.1 # mean and standard deviation
s = np.random.normal(mu, sigma, 1000)

# %%
# Return first 10 items in array
s[:10]
# Out:
# array([ 0.00212002,  0.03689842, -0.10536356, -0.04145461, -0.08135192,
#         0.15521503,  0.16326247,  0.23584255,  0.01448809,  0.03534575])

# %%
abs(mu - np.mean(s))
# Out:
# 0.003535253419748114

# %%
abs(sigma - np.std(s, ddof=1))
# Out:
# 0.004751995079395249

# %%
count, bins, ignored = plt.hist(s, 30, density=True)
f = 1/(sigma * np.sqrt(2 * np.pi)) * np.exp(-(bins - mu) ** 2/(2 * sigma**2));
plt.plot(bins, f, linewidth=2)
plt.show()

# %% [markdown]
# ## References
# [1] https://www.datacamp.com/community/tutorials/numpy-random

# %% [markdown]
# ## End
